# %% [markdown]
# Please note that the following code is taken from the book "AI and Machine Learning for Coders" with minor modifications to accommodate the lectures on "Introduction to Machine Learning", which is a part of the course CSI4106 "Introduction to Artificial Intelligence" taught in Winter 2022.
#
# Moroney, Laurence. AI and Machine Learning for Coders. O'Reilly Media.
#
# Please do not redistribute the code.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

with tf.device('/GPU:0'):
    model = Sequential([
        Dense(units=1, input_shape=[1,])
    ])

    model.compile(optimizer='sgd', loss='mean_squared_error')

    xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
    ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

    model.fit(xs, ys, epochs=100)

    print(model.predict([5.0]))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 139ms/step - loss: 0.6325
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6128
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5949
# Epoch 4/100
# 1/1 [==============================] - 0s 999us/step - loss: 0.5786
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5634
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5493
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5360
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5234
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5114
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4999
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4888
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4782
# ...
